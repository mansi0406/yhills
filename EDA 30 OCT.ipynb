# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
sns.set(style="dark")

# %%
df=pd.read_csv("Absenteeism_at_work.csv",sep=";")      #because it is sepreated by semi-colon

# %%
df.head(30).style.background_gradient(cmap="Dark2_r")
# Out:
# <style type="text/css">
# #T_59fcf_row0_col0, #T_59fcf_row0_col3, #T_59fcf_row0_col16, #T_59fcf_row1_col3, #T_59fcf_row1_col13, #T_59fcf_row2_col5, #T_59fcf_row3_col1, #T_59fcf_row4_col0, #T_59fcf_row4_col16, #T_59fcf_row5_col5, #T_59fcf_row6_col0, #T_59fcf_row6_col13, #T_59fcf_row7_col8, #T_59fcf_row8_col0, #T_59fcf_row8_col8, #T_59fcf_row8_col19, #T_59fcf_row9_col13, #T_59fcf_row9_col16, #T_59fcf_row10_col8, #T_59fcf_row11_col3, #T_59fcf_row11_col8, #T_59fcf_row12_col8, #T_59fcf_row13_col5, #T_59fcf_row14_col5, #T_59fcf_row16_col5, #T_59fcf_row17_col5, #T_59fcf_row18_col5, #T_59fcf_row18_col19, #T_59fcf_row19_col16, #T_59fcf_row20_col1, #T_59fcf_row20_col19, #T_59fcf_row21_col5, #T_59fcf_row22_col0, #T_59fcf_row22_col13, #T_59fcf_row23_col8, #T_59fcf_row24_col0, #T_59fcf_row24_col16, #T_59fcf_row25_col0, #T_59fcf_row25_col13, #T_59fcf_row26_col0, #T_59fcf_row26_col3, #T_59fcf_row26_col16, #T_59fcf_row27_col17, #T_59fcf_row28_col0, #T_59fcf_row28_col16, #T_59fcf_row29_col5 {
# ...

# %%
df.head(30).style.background_gradient(cmap="viridis")
# Out:
# <style type="text/css">
# #T_4caec_row0_col0, #T_4caec_row4_col0, #T_4caec_row24_col0, #T_4caec_row26_col0, #T_4caec_row28_col0 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_4caec_row0_col1 {
#   background-color: #d0e11c;
#   color: #000000;
# }
# ...

# %%
df.head(30).style.background_gradient(cmap="plasma")
# Out:
# <style type="text/css">
# #T_8e493_row0_col0, #T_8e493_row4_col0, #T_8e493_row24_col0, #T_8e493_row26_col0, #T_8e493_row28_col0 {
#   background-color: #8b0aa5;
#   color: #f1f1f1;
# }
# #T_8e493_row0_col1 {
#   background-color: #fada24;
#   color: #000000;
# }
# ...

# %%
df.head(30).style.background_gradient(cmap="inferno")
# Out:
# <style type="text/css">
# #T_1d7c8_row0_col0, #T_1d7c8_row4_col0, #T_1d7c8_row24_col0, #T_1d7c8_row26_col0, #T_1d7c8_row28_col0 {
#   background-color: #65156e;
#   color: #f1f1f1;
# }
# #T_1d7c8_row0_col1 {
#   background-color: #f3e55d;
#   color: #000000;
# }
# ...

# %%
df.head(30).style.background_gradient(cmap="Oranges")
# Out:
# <style type="text/css">
# #T_6b871_row0_col0, #T_6b871_row4_col0, #T_6b871_row24_col0, #T_6b871_row26_col0, #T_6b871_row28_col0 {
#   background-color: #fdc692;
#   color: #000000;
# }
# #T_6b871_row0_col1 {
#   background-color: #952f03;
#   color: #f1f1f1;
# }
# ...

# %%
df.head(30).style.background_gradient(cmap="Greys")
# Out:
# <style type="text/css">
# #T_77aed_row0_col0, #T_77aed_row4_col0, #T_77aed_row24_col0, #T_77aed_row26_col0, #T_77aed_row28_col0 {
#   background-color: #d1d1d1;
#   color: #000000;
# }
# #T_77aed_row0_col1 {
#   background-color: #151515;
#   color: #f1f1f1;
# }
# ...

# %%
df.shape
# Out:
# (740, 21)

# %%
df.dtypes
# Out:
# ID                                   int64
# Reason for absence                   int64
# Month of absence                     int64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense               int64
# Distance from Residence to Work      int64
# Service time                         int64
# Age                                  int64
# Work load Average/day              float64
# Hit target                           int64
# Disciplinary failure                 int64
# Education                            int64
# Son                                  int64
# Social drinker                       int64
# Social smoker                        int64
# Pet                                  int64
# Weight                               int64
# Height                               int64
# Body mass index                      int64
# Absenteeism time in hours            int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
df.info() #no encoding req
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    float64
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %%
df.drop("ID",axis=1,inplace=True)

# %%
df.shape
# Out:
# (740, 20)

# %%
df.describe().style.background_gradient(cmap="Greys")
# Out:
# <style type="text/css">
# #T_166bd_row0_col0, #T_166bd_row0_col1, #T_166bd_row0_col2, #T_166bd_row0_col3, #T_166bd_row0_col4, #T_166bd_row0_col5, #T_166bd_row0_col6, #T_166bd_row0_col7, #T_166bd_row0_col8, #T_166bd_row0_col9, #T_166bd_row0_col10, #T_166bd_row0_col11, #T_166bd_row0_col12, #T_166bd_row0_col13, #T_166bd_row0_col14, #T_166bd_row0_col15, #T_166bd_row0_col16, #T_166bd_row0_col17, #T_166bd_row0_col18, #T_166bd_row0_col19 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_166bd_row1_col0, #T_166bd_row1_col18, #T_166bd_row3_col7, #T_166bd_row4_col18, #T_166bd_row5_col0, #T_166bd_row5_col5, #T_166bd_row5_col18 {
#   background-color: #fcfcfc;
#   color: #000000;
# }
# #T_166bd_row1_col1, #T_166bd_row1_col19, #T_166bd_row2_col0, #T_166bd_row2_col5, #T_166bd_row4_col5, #T_166bd_row4_col6, #T_166bd_row5_col1, #T_166bd_row6_col1, #T_166bd_row6_col19, #T_166bd_row7_col15 {
#   background-color: #fefefe;
#   color: #000000;
# }
# ...

# %%
df["Month of absence"].value_counts()
# Out:
# 3     87
# 2     72
# 10    71
# 7     67
# 5     64
# 11    63
# 8     54
# 6     54
# 9     53
# 4     53
# 1     50
# 12    49
# 0      3
# Name: Month of absence, dtype: int64

# %%
df["Month of absence"].replace(0,3,inplace=True)

# %%
df["Month of absence"].value_counts()
# Out:
# 3     90
# 2     72
# 10    71
# 7     67
# 5     64
# 11    63
# 8     54
# 6     54
# 9     53
# 4     53
# 1     50
# 12    49
# Name: Month of absence, dtype: int64

# %%
df.skew()
# Out:
# Reason for absence                -0.915312
# Month of absence                   0.081737
# Day of the week                    0.102440
# Seasons                           -0.038532
# Transportation expense             0.396189
# Distance from Residence to Work    0.312083
# Service time                      -0.004720
# Age                                0.697703
# Work load Average/day              0.961457
# Hit target                        -1.261708
# Disciplinary failure               3.952270
# Education                          2.108953
# Son                                1.086465
# Social drinker                    -0.273327
# Social smoker                      3.290333
# Pet                                2.735715
# Weight                             0.017001
# Height                             2.566060
# Body mass index                    0.305046
# Absenteeism time in hours          5.720728
# dtype: float64

# %%
sns.distplot(df['Absenteeism time in hours'])
plt.show()

# %%
sns.distplot(df['Hit target'])
plt.show()

# %%
sns.distplot(df['Weight'])
plt.show()

# %%
sns.distplot(df['Month of absence'])
plt.show()

# %%
sns.distplot(df['Service time'])
plt.show()

# %%
sns.distplot(df['Reason for absence'])
plt.show()

# %%
bar_colors=["blue","purple","pink","red"]
df["Seasons"].value_counts().plot(kind="bar",color=bar_colors)
plt.title("absence in diff seasons")
plt.xlabel("Seasons")
plt.ylabel("frequency")
plt.show()

# %%
df["Body mass index"].value_counts().plot(kind="bar")
plt.title("bmi in diff seasons")
plt.xlabel("bmi")
plt.ylabel("frequency")
plt.show()

# %%
bar_colors=["blue","purple","pink","red"]
df["Education"].value_counts().plot(kind="bar",color=bar_colors)
plt.title("education in diff seasons")
plt.xlabel("Education level")
plt.ylabel("frequency")
plt.show()

# %%
bar_colors=["purple","pink"]
df["Social drinker"].value_counts().plot(kind="bar",color=bar_colors)
plt.title("social drinker taking leave")
plt.xlabel("Social drinker")
plt.ylabel("absence")
plt.show()

# %%
bar_colors=["purple","pink"]
df["Social smoker"].value_counts().plot(kind="bar",color=bar_colors)
plt.title("social smoker taking leave")
plt.xlabel("Social smoker")
plt.ylabel("absence")
plt.show()

# %%
corr=df.corr() #too much data use heatmap
corr
# Out:
#                                  Reason for absence  Month of absence  \
# Reason for absence                         1.000000         -0.092395
# Month of absence                          -0.092395          1.000000
# Day of the week                            0.116319         -0.005512
# Seasons                                   -0.117925          0.408072
# Transportation expense                    -0.119381          0.135803
# Distance from Residence to Work            0.161831         -0.003498
# Service time                               0.048425         -0.062274
# Age                                       -0.078608          0.002624
# Work load Average/day                     -0.123472         -0.170867
# Hit target                                 0.088943         -0.462376
# Disciplinary failure                      -0.545054          0.107637
# Education                                 -0.047357         -0.068004
# ...

# %%
plt.figure(figsize=(16,12))
sns.heatmap(corr,annot=True)
plt.show()

# %%
plt.rcParams['figure.figsize']=(16,18)
sns.boxplot(x="Age",y="Absenteeism time in hours",data=df)
plt.show()

# %%
plt.rcParams['figure.figsize']=(16,18)
sns.boxplot(x="Son",y="Absenteeism time in hours",data=df)
plt.show()

# %%
sns.pairplot(df)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
#lets build our linear model
# independent variables
X=df.drop(['Absenteeism time in hours'],axis=1)
#dependent variable
y=df[['Absenteeism time in hours']]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=0)

# %%
model_1= LinearRegression()
model_1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model_1.score(X_train,y_train)
# Out:
# 0.16265091440527224

# %%
model_1.score(X_test,y_test)
# Out:
# 0.0818117414212507

# %% [markdown]
# # polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model

# %%
poly = PolynomialFeatures(degree=2, interaction_only=True)
X_train2=poly.fit_transform(X_train)
X_test2 =poly.fit_transform(X_test)
poly_clf =linear_model.LinearRegression()
poly_clf.fit(X_train2, y_train)
#In sample (training) R^2 will always improve with the number of variables!
print(poly_clf.score(X_train2,y_train))
# Out:
# 0.42925423709068145

# %%
print(poly_clf.score(X_test2,y_test))
# Out:
# -1.7471707687171598

# %% [markdown]
# # svr

# %%
from sklearn.svm import SVR

# %%
model_svr=SVR(kernel="poly")

# %%
model_svr.fit(X_train,y_train)
# Out:
# SVR(kernel='poly')

# %%
model_svr.score(X_train,y_train)
# Out:
# -0.05620607787449905

# %%
model_svr.score(X_test,y_test)
# Out:
# -0.06519546489514405

# %% [markdown]
# ## preprocessing Techniques

# %%
from scipy.stats import zscore

# %%
Xscaled=X.apply(zscore)

# %%
X_train,X_test,y_train,y_test=train_test_split(Xscaled,y,test_size=0.30,random_state=0)

# %%
model_2= LinearRegression()
model_2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model_2.score(X_train,y_train)
# Out:
# 0.16265091440527213

# %%
model_2.score(X_test,y_test)
# Out:
# 0.0818117414212508

# %%
model_svr1=SVR(kernel="poly")

# %%
model_svr1.fit(X_train,y_train)
# Out:
# SVR(kernel='poly')

# %%
model_svr1.score(X_train,y_train)
# Out:
# 0.029526029791707376

# %%
model_svr1.score(X_test,y_test)
# Out:
# 0.037537448708534704
